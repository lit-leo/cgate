# %%
import torch
from config import cfg 
from src.visualization import visualize_sparsity

# %%
r"""Here we load
    torch.Tensor, with row i representing quality on the i-th task
        and column j specifying the snapshot moment:
        the quality is checked after tasks 0..j had been fitted
        and relevant kernels frozen."""

torch.load('results/sigmoid_lambda1e-1_200ep/task_incremental_acc.pt')
# Out:
# tensor([[0.9838, 0.9838, 0.9838, 0.9838, 0.9838],
#         [0.0000, 0.9031, 0.9031, 0.9031, 0.9031],
#         [0.0000, 0.0000, 0.9270, 0.9270, 0.9270],
#         [0.0000, 0.0000, 0.0000, 0.9668, 0.9668],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.9590]])

# %%
visualize_sparsity('results/sigmoid_lambda1e-1_200ep')
